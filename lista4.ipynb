# %% [markdown]
# <a href="https://colab.research.google.com/github/luscabr1/aulapython/blob/master/lista4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Disciplina: Probabilidade e Estatística
# Aluno: Lucas Oliveira Dos Santos
# Lista 4

#Questão 1
Lados = int(input('Quantidade de lados: '))   #para o usuario inserir os valores
lado = float(input('Medida do lado: '))


if Lados == 3:
        area = lado ** 2 * 3 ** (1/2) / 4   #calculo da area
        print("Triângulo")
        print("área: %.2fcm²"%area)
        
elif Lados == 4:
        area = lado ** 2
        print("quadrado")
        print("área: %.2fcm²"%area)
elif Lados == 5:
        print("Pentágono")



#Questão 2

Lados = int(input('Quantidade de lados: '))   #para o usuario inserir os valores
lado = float(input('Medida do lado: '))


if Lados == 3:
        area = lado ** 2 * 3 ** (1/2) / 4   #calculo da area
        print("Triângulo")
        print("área: %.2fcm²"%area)
if Lados <3:
    print("Não é um polígono")        
elif Lados == 4:
        area = lado ** 2
        print("quadrado")
        print("área: %.2fcm²"%area)
elif Lados == 5:
        print("Pentágono")
if Lados >5:
    print("Polígono não identificado")

#Questão 3

a = 10
b = 20
c = 30
print(c)

#Questão 4




















#Questão 5
tr = int(input('Valor de tr: '))
to = int(input('Valor de to: '))
ta = int(input('Valor de ta: '))

if tr == 90:
    print("Triângulo retângulo")
if  to > 90:
    print("Triângulo obtusângulo")
if  ta < 90:
    print("Triângulo Acutângulo") 


#Questão 6

num = 0

while (num < 5):
    print(num)
    num  = num + 1

#Questão 7

num = int(input('Digite um numero: '))

if num < 1:
    print("Entrada inválida")
if num > 4:
    print("Entrada inválida")
else :
    print(num)
